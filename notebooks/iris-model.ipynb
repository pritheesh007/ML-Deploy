# %%
# !pip install pandas
# Out:
# ...
#    ---------------------------------------- 0.0/9.8 MB ? eta -:--:--
#    ----- ---------------------------------- 1.3/9.8 MB 7.5 MB/s eta 0:00:02
#    ------------- -------------------------- 3.4/9.8 MB 8.8 MB/s eta 0:00:01
#    ----------------------- ---------------- 5.8/9.8 MB 9.8 MB/s eta 0:00:01
#    --------------------------------- ------ 8.1/9.8 MB 10.1 MB/s eta 0:00:01
#    ---------------------------------------  9.7/9.8 MB 10.1 MB/s eta 0:00:01
#    ---------------------------------------- 9.8/9.8 MB 9.7 MB/s  0:00:01
# ...

# %%
# !pip install scikit-learn
# Out:
# ...
#    ---------------------------------------- 0.0/8.2 MB ? eta -:--:--
#    -------- ------------------------------- 1.8/8.2 MB 9.1 MB/s eta 0:00:01
#    ----------------- ---------------------- 3.7/8.2 MB 9.5 MB/s eta 0:00:01
#    ----------------------------- ---------- 6.0/8.2 MB 10.2 MB/s eta 0:00:01
#    ---------------------------------------- 8.2/8.2 MB 10.6 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/36.6 MB ? eta -:--:--
#    -- ------------------------------------- 1.8/36.6 MB 9.1 MB/s eta 0:00:04
#    ---- ----------------------------------- 3.9/36.6 MB 9.8 MB/s eta 0:00:04
#    ------ --------------------------------- 6.0/36.6 MB 10.3 MB/s eta 0:00:03
#    -------- ------------------------------- 7.9/36.6 MB 9.7 MB/s eta 0:00:03
#    ---------- ----------------------------- 9.7/36.6 MB 9.4 MB/s eta 0:00:03
#    ------------ --------------------------- 11.5/36.6 MB 9.4 MB/s eta 0:00:03
# ...

# %%
import pandas as pd
import pickle
from sklearn.linear_model import LogisticRegression

# %%
df = pd.read_csv(r"C:\Users\Pritheesh\Downloads\iris_data.csv")
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
df.shape
# Out:
# (150, 5)

# %%
x = df.iloc[:,:-1]
y = df.iloc[:,-1]
